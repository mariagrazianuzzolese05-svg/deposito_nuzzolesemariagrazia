# %%
import numpy as np

import matplotlib.pyplot as plt


from tensorflow.keras.datasets import mnist

from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Dense, Flatten

from tensorflow.keras.utils import to_categorical
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#       6 from tensorflow.keras.datasets import mnist
#       8 from tensorflow.keras.models import Sequential
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
from keras.models import Sequential

from keras.layers import Dense


model = Sequential()

model.add(Dense(64, activation='relu', input_dim=100))

model.add(Dense(10, activation='softmax'))

# %%
from keras.layers import Input, Dense

from keras.models import Model


inputs = Input(shape=(100,))

x = Dense(64, activation='relu')(inputs)

outputs = Dense(10, activation='softmax')(x)

model = Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model.summary()
#
# NameError: name 'model' is not defined

# %%
model.compile(optimizer='adam',

              loss='categorical_crossentropy',#calcola errore e calcola confidenza sull'errore

              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5, batch_size=32)

# %%
#qui dà valore senza addestrarsi
loss_and_metrics = model.evaluate(x_test, y_test, batch_size=128)

predictions = model.predict(x_new)
# Out:
#   Cell In[5], line 2
#     pip install Numpy
#         ^
# SyntaxError: invalid syntax

# %%
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras import layers # Oppure: from keras.layers import Dense, Flatten
from keras.utils import to_categorical

# %%
# Creazione del modello

model = Sequential()


# Aggiunta degli strati

model.add(Dense(units=128, activation='relu', input_shape=(784,)))

model.add(Dense(units=64, activation='relu'))

model.add(Dense(units=10, activation='softmax'))
